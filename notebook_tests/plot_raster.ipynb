# %%
import rasterio
import matplotlib.pyplot as plt
from rasterio.plot import show
import numpy as np

# %%
# Open the raster file
with rasterio.open('/home/thpc/workspace/pfas_map_ml/data/summa/HUC8_CA_PFAS_GTruth_Summa3.tiff') as src:
    # Read the data
    raster_data = src.read(1)  # Read the first band, or use src.read() to get all bands
    print(src.height, src.width)
    # Plot using rasterio's built-in plotting function
    fig, ax = plt.subplots(figsize=(8, 6))
    show(raster_data, ax=ax, cmap='gray')  # Use a colormap like 'gray' or any other

    # Optionally, you can overlay the raster's bounds
    show(src, ax=ax, cmap='gray')

plt.title('Raster Plot')
plt.show()
# Out:
# 9469 10215

# %%
# Open the raster file
with rasterio.open('/home/thpc/workspace/pfas_map_ml/data/temp_tiff/2022_averaged_Lead_data_Q1.tiff') as src:
    # Read the data
    raster_data = src.read(1)  # Read the first band, or use src.read() to get all bands
    print(src.height, src.width)
    print(np.unique(raster_data))
    # Plot using rasterio's built-in plotting function
    fig, ax = plt.subplots(figsize=(8, 6))
    show(raster_data, ax=ax, cmap='gray')  # Use a colormap like 'gray' or any other

    # Optionally, you can overlay the raster's bounds
    show(src, ax=ax, cmap='gray')

plt.title('Raster Plot')
plt.show()
# Out:
# 9469 10215
# [-10.          1.          1.00065     1.0008425   1.001125    1.0028545
#    1.003355    1.0037075   1.0039015   1.0042088   1.0050542   1.0050666
#    1.0053365   1.0057334   1.0067333   1.006972    1.0087931   1.0100462
#    1.0127143   1.013       1.0132333   1.0157262   1.0259334   1.0357273]
